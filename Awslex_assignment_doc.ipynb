# %% [markdown]
# *AMAZONLEX CHATBOT ASSIGNMENT*

# %% [markdown]
# Assignment Task:
# *Create a project in PyCharm to scrap the reviews from flipkart site.
# *Create a chatbot in Amazonlex.
# *Deploy and integrate with Facebook page.

# %% [markdown]
# For building the chatbot in Amazonlex, we have to sign up in amazon.
# After login, i created the bot in the name of "Amazonlexapp".
# The step by step process with screenshots are given below.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/aws_iam_credent.png")

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/1test_bot_creat.png")

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/2intent_creat.png")

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/aws_1.png")

# %% [markdown]
# In the amazonlex_assignment, i created two intents in the name of welcome and review.
# In welcome intent, greetings messages and their response are created.
# In review intent, lambda function, slots and their response are created.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/aws_2.png")

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/aws_3.png")

# %% [markdown]
# After testing the lambda functions, run the pycharm code.
# Above screenshot shows that the app is running successfully.
# Run ngrok.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/aws_ngrok.png")

# %% [markdown]
# Then save the intents and build the bot.
# Test the bot with different set of questions.
# It shows the reviews of iphone,tv,bag from flipkart.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/aws_4.png")

# %% [markdown]
# The built and tested successfully.
# Now we have to publish the bot.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/aws_publish1.png")

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/aws_publish2.png")

# %% [markdown]
# Deployment on Facebook
# *Create a app in facebook developer app.
# *Create a page for the app to integrate.
# *Integrate with messanger.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/8fb_developers.png")

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/aws_fb1.png")

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/aws_fb_token.png")

# %% [markdown]
# Save the below details:
# Channelname:Awslexapp
# Alias:Awslexapp
# verifytoken:awslextoken

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/aws_fb.png")

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/aws_fb_final.png")

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/AWS/aws_fb_final1.png")

# %% [markdown]
# From above all the steps, i successfully deployed my app in facebook.
